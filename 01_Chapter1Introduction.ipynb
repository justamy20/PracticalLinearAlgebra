# %% [markdown]
# <a href="https://colab.research.google.com/github/justamy20/PracticalLinearAlgebra/blob/main/01_Chapter1Introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chapter 1 — Introduction
#
# ## Practical Linear Algebra for Data Science
# ### Mike X Cohen

# %% [markdown]
# # Introduction
#
# Linear algebra merupakan dasar penting dalam:
#
# - Data Science
# - Machine Learning
# - Artificial Intelligence
# - Computer Graphics
# - Scientific Computing
#
# Buku ini berfokus pada implementasi practical linear algebra
# menggunakan Python dan NumPy.

# %%
import numpy as np

# %% [markdown]
# # Example of NumPy Array
#
# NumPy digunakan untuk merepresentasikan vector dan matrix.

# %%
v = np.array([1,2,3])

print(v)
print(v.shape)

# %% [markdown]
# Vector di atas memiliki 3 elemen
# dengan shape `(3,)`.

# %% [markdown]
# # Summary
#
# Pada chapter ini dipelajari:
#
# - pentingnya linear algebra,
# - penggunaan NumPy,
# - representasi vector sederhana di Python.
